# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords

import json
import torch
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from nltk.corpus import stopwords
from scipy.spatial.distance import cdist
from transformers import BertModel, BertTokenizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package punkt to /Users/relax/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/relax/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
'''Remove stopwords from claim and evidence for reducing the computational consumption'''
def stopwords_func(stop_words, text_type, text_data):
    if text_type == "evidence":
        for i in text_data:
            sentence = text_data[i]
            words = sentence.split()
            filtered_words = [word for word in words if word.lower() not in stop_words]
            filtered_sentence = " ".join(filtered_words)
            text_data[i] = filtered_sentence
    else:
        for i in text_data.values():
            sentence = i["claim_text"]
            words = sentence.split()
            filtered_words = [word for word in words if word.lower() not in stop_words]
            filtered_sentence = " ".join(filtered_words)
            i["claim_text"] = filtered_sentence
    return text_data

'''Function for picking random keys from the dictionary after excluding the specified key(s)'''
def pick_random_keys(dictionary, excluded_keys, num_keys):
    available_keys = [key for key in dictionary.keys() if key not in excluded_keys]
    random_keys = random.sample(available_keys, num_keys)
    return random_keys

'''Function for turning the text into lowercase expression'''
def lower_processing(data, text_type):
    if text_type == "claim_text":
        for i in data:
            data[i][text_type] = data[i][text_type].lower()
    else:
        for i in data:
            data[i] = data[i].lower()
    return data

# %%
## Read in data
# Read in training data (claim)
with open('../project-data/train-claims.json', 'r') as tclaim_file:
    tclaim_data = json.load(tclaim_file)

# Read in development data (claim)
with open('../project-data/dev-claims.json', 'r') as dclaim_file:
    dclaim_data = json.load(dclaim_file)

# Read in test data (claim)
with open('../project-data/test-claims-unlabelled.json', 'r') as uclaim_file:
    uclaim_data = json.load(uclaim_file)

# Read in evidence data
with open('../project-data/evidence.json', 'r') as evi_file:
    evi_data = json.load(evi_file)

## Preprocessing - Lowercase operation of the case
tclaim_data = lower_processing(tclaim_data, "claim_text")
dclaim_data = lower_processing(dclaim_data, "claim_text")
uclaim_data = lower_processing(uclaim_data, "claim_text")
evi_data = lower_processing(evi_data, 'evidence')

## Create claim-evidence pair based on training set
tkey_list = list(tclaim_data.keys())
train_pairs = []
evi_keys = []
labels = []
for i in tclaim_data:
    for j in tclaim_data[i]["evidences"]:
        evi_keys.append(j)
        train_pairs.append((i, tclaim_data[i]["claim_text"], evi_data[j], j))
        labels.append(1)
  
## insert negative sample to the training set
random.seed(1)
for i in tclaim_data:
    excluded_keys = tclaim_data[i]["evidences"]
    random_keys = pick_random_keys(evi_data, excluded_keys, len(excluded_keys))
    for j in random_keys:
        evi_keys.append(j)
        train_pairs.append((i, tclaim_data[i]["claim_text"], evi_data[j], j))
        labels.append(0)

# %%
# Store the claim, evidence sentence(s) to list for embedded usage
claim_train_sentence = []
claim_dep_sentence = []
claim_test_sentence = []
evidence_full_sentence = []
evidence_sample_sentence = []

for i in tclaim_data.values():
    claim_train_sentence.append(i["claim_text"])
for i in dclaim_data.values():
    claim_dep_sentence.append(i["claim_text"])
for i in uclaim_data.values():
    claim_test_sentence.append(i["claim_text"])
for i in evi_data.values():
    evidence_full_sentence.append(i)
tfidf_keys = []
for i in train_pairs[:int(len(train_pairs)/2)]:
  if i[2] not in evidence_sample_sentence:
    evidence_sample_sentence.append(i[2])
    tfidf_keys.append(i[3])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Sample training data
train_data = claim_train_sentence + claim_dep_sentence + evidence_full_sentence

# Initialize TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit the vectorizer on the training data
tfidf_vectorizer.fit(train_data)

# Transform the training and test data using the trained vectorizer
train_embeddings = tfidf_vectorizer.transform(claim_train_sentence)
test_embeddings = tfidf_vectorizer.transform(claim_test_sentence)

# %%
train_claim_list = tclaim_data.keys()
train_claim_list
# Out:
# dict_keys(['claim-1937', 'claim-126', 'claim-2510', 'claim-2021', 'claim-2449', 'claim-851', 'claim-2773', 'claim-949', 'claim-1019', 'claim-2834', 'claim-1441', 'claim-1181', 'claim-2417', 'claim-2152', 'claim-826', 'claim-1066', 'claim-3003', 'claim-3059', 'claim-568', 'claim-60', 'claim-378', 'claim-2486', 'claim-1782', 'claim-1235', 'claim-2065', 'claim-1390', 'claim-2789', 'claim-1414', 'claim-377', 'claim-558', 'claim-1447', 'claim-1038', 'claim-2794', 'claim-930', 'claim-2763', 'claim-1920', 'claim-2961', 'claim-1395', 'claim-1404', 'claim-2257', 'claim-646', 'claim-1545', 'claim-1317', 'claim-1547', 'claim-2280', 'claim-118', 'claim-1357', 'claim-69', 'claim-2849', 'claim-499', 'claim-749', 'claim-428', 'claim-1837', 'claim-1875', 'claim-1324', 'claim-1980', 'claim-409', 'claim-2193', 'claim-3084', 'claim-1227', 'claim-1499', 'claim-1790', 'claim-2090', 'claim-2199', 'claim-1498', 'claim-1792', 'claim-2540', 'claim-2474', 'claim-2741', 'claim-3102', 'claim-1112', 'claim-2488', 'claim-1802', 'claim-815', 'claim-2698', 'claim-1142', 'claim-2707', 'claim-1260', 'claim-1163', 'claim-740', 'claim-1061', 'claim-2283', 'claim-1822', 'claim-332', 'claim-258', 'claim-774', 'claim-207', 'claim-2966', 'claim-450', 'claim-362', 'claim-2547', 'claim-716', 'claim-1708', 'claim-1678', 'claim-1334', 'claim-61', 'claim-1826', 'claim-157', 'claim-1481', 'claim-1796', 'claim-807', 'claim-1658', 'claim-493', 'claim-2485', 'claim-2222', 'claim-2606', 'claim-534', 'claim-1313', 'claim-1505', 'claim-282', 'claim-957', 'claim-132', 'claim-1814', 'claim-363', 'claim-2687', 'claim-1294', 'claim-649', 'claim-2868', 'claim-1562', 'claim-1620', 'claim-1327', 'claim-3103', 'claim-195', 'claim-642', 'claim-2494', 'claim-1116', 'claim-3048', 'claim-1115', 'claim-1614', 'claim-1580', 'claim-593', 'claim-2560', 'claim-11', 'claim-1339', 'claim-1878', 'claim-2120', 'claim-1098', 'claim-2078', 'claim-797', 'claim-1667', 'claim-2553', 'claim-2029', 'claim-1049', 'claim-1744', 'claim-2782', 'claim-2432', 'claim-2805', 'claim-821', 'claim-1931', 'claim-1084', 'claim-2788', 'claim-1465', 'claim-1938', 'claim-2123', 'claim-1406', 'claim-2444', 'claim-320', 'claim-1880', 'claim-263', 'claim-663', 'claim-1995', 'claim-2780', 'claim-2369', 'claim-2627', 'claim-1077', 'claim-828', 'claim-2461', 'claim-2945', 'claim-2633', 'claim-353', 'claim-1829', 'claim-1568', 'claim-791', 'claim-1634', 'claim-2202', 'claim-337', 'claim-1674', 'claim-2255', 'claim-1988', 'claim-1376', 'claim-2649', 'claim-1923', 'claim-133', 'claim-2927', 'claim-688', 'claim-1712', 'claim-1817', 'claim-2067', 'claim-3052', 'claim-1157', 'claim-1246', 'claim-564', 'claim-1866', 'claim-1454', 'claim-129', 'claim-1616', 'claim-1948', 'claim-614', 'claim-868', 'claim-1665', 'claim-2453', 'claim-2267', 'claim-390', 'claim-216', 'claim-905', 'claim-2826', 'claim-2775', 'claim-2141', 'claim-2482', 'claim-582', 'claim-708', 'claim-412', 'claim-1855', 'claim-1999', 'claim-3130', 'claim-85', 'claim-2030', 'claim-470', 'claim-1932', 'claim-2506', 'claim-1825', 'claim-1007', 'claim-1205', 'claim-1783', 'claim-2365', 'claim-548', 'claim-2256', 'claim-3121', 'claim-2238', 'claim-2844', 'claim-789', 'claim-1143', 'claim-638', 'claim-1293', 'claim-1793', 'claim-1631', 'claim-382', 'claim-2052', 'claim-2304', 'claim-622', 'claim-2245', 'claim-2835', 'claim-1314', 'claim-2821', 'claim-666', 'claim-788', 'claim-802', 'claim-1827', 'claim-1688', 'claim-366', 'claim-967', 'claim-2886', 'claim-1082', 'claim-2746', 'claim-519', 'claim-1119', 'claim-424', 'claim-1606', 'claim-1279', 'claim-344', 'claim-2689', 'claim-358', 'claim-630', 'claim-633', 'claim-2384', 'claim-2536', 'claim-1512', 'claim-2953', 'claim-2127', 'claim-1576', 'claim-1170', 'claim-565', 'claim-2288', 'claim-3039', 'claim-1844', 'claim-168', 'claim-1067', 'claim-1183', 'claim-1625', 'claim-2032', 'claim-57', 'claim-1544', 'claim-2549', 'claim-446', 'claim-2591', 'claim-1890', 'claim-51', 'claim-2779', 'claim-2856', 'claim-2358', 'claim-982', 'claim- ...

# %%
k = 11
train_claim_list = list(tclaim_data.keys())
label_potential_list = []
for claim_id, claim_value in uclaim_data.items():
    test_claim_text = claim_value["claim_text"]
    test_claim_emb = tfidf_vectorizer.transform([test_claim_text])
    evi_sim_dict = {}
    sim = cosine_similarity(test_claim_emb, train_embeddings)[0]

    for i in range(len(sim)):
        evi_sim_dict[train_claim_list[i]] = sim[i]
    s_sim = [(k, v) for k, v in sorted(evi_sim_dict.items(), key=lambda item: item[1],reverse=True)][:k]
    label_list = []
    for i in s_sim:
        label_list.append(i[0])
    label_potential_list.append(label_list)

# %%
with open('../test-claims-predictions.json', 'r') as final_json:
    final_test = json.load(final_json)
test_key_list = list(final_test.keys())

def most_frequent_element(nums):
    return max(set(nums), key=nums.count)

majority_label_list = []
for i in range(len(label_potential_list)):
    po_label = []
    for j in label_potential_list[i]:
        po_label.append(tclaim_data[j]["claim_label"])
    test_class = (most_frequent_element(po_label))
    final_test[test_key_list[i]]["claim_label"] = test_class

file_path = '../test-claims-predictions.json'
with open(file_path, 'w') as json_file:
    json.dump(final_test, json_file)

# %%
final_test
# Out:
# {'claim-2967': {'claim_text': 'The contribution of waste heat to the global climate is 0.028 W/m2.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-308923',
#    'evidence-22107',
#    'evidence-213569',
#    'evidence-560239',
#    'evidence-88593',
#    'evidence-127889']},
#  'claim-979': {'claim_text': '“Warm weather worsened the most recent five-year drought, which included the driest four-year period on record in terms of statewide precipitation.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-937309',
#    'evidence-957389',
#    'evidence-178433',
#    'evidence-268048',
#    'evidence-434754',
#    'evidence-435808']},
#  'claim-1609': {'claim_text': 'Greenland has only lost a tiny fraction of its ice mass.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-776422',
#    'evidence-52981',
#    'evidence-966882',
#    'evidence-264761',
#    'evidence-510677',
#    'evidence-408551']},
#  'claim-1020': {'claim_text': '“The global reef crisis does not necessarily mean extinction for coral species.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-984807',
#    'evidence-369927',
#    'evidence-283852',
#    'evidence-180670',
#    'evidence-33957',
#    'evidence-1110959']},
#  'claim-2599': {'claim_text': 'Small amounts of very active substances can cause large effects.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-780630',
#    'evidence-834109',
#    'evidence-780227',
#    'evidence-432221',
#    'evidence-351638',
#    'evidence-979098']},
#  'claim-2110': {'claim_text': "They changed the name from 'global warming' to 'climate change'",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-377592',
#    'evidence-891739',
#    'evidence-462034',
#    'evidence-109016',
#    'evidence-256898',
#    'evidence-1175928']},
#  'claim-1135': {'claim_text': 'Scientists confirm a mass bleaching event on the Great Barrier Reef this year has killed more corals than ever before, with more than two thirds destroyed across large swathes of the biodiverse site.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-688029',
#    'evidence-670186',
#    'evidence-1198124',
#    'evidence-323266',
#    'evidence-512289',
#    'evidence-1053803']},
#  'claim-712': {'claim_text': '“Instead of a three-foot increase in ocean levels by the end of the century, six feet was more likely, according to DeConto and Pollard’s findings.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-117714',
#    'evidence-457639',
#    'evidence-252819',
#    'evidence-98633',
#    'evidence-1137703',
#    'evidence-710636']},
#  'claim-1307': {'claim_text': 'a new study by scientists at the Australian Research Council finds that the ongoing bleaching event is mainly due to human-caused global warming, and that if global warming proceeds as currently expected, “large parts” of the Great Barrier Reef could die by the mid-2030s.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-512289',
#    'evidence-670186',
#    'evidence-1197417',
#    'evidence-534165',
#    'evidence-88827',
#    'evidence-759896']},
#  'claim-148': {'claim_text': 'Previous IPCC reports tended to assume that clouds would have a neutral impact because the warming and cooling feedbacks would cancel each other out.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-37274',
#    'evidence-448411',
#    'evidence-712289',
#    'evidence-669368',
#    'evidence-239881',
#    'evidence-1091739']},
#  'claim-903': {'claim_text': 'Growers regularly pump CO2 into greenhouses, raising levels to three times that of the natural environment, to produce stronger, greener, healthier plants.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-906133',
#    'evidence-561302',
#    'evidence-185417',
#    'evidence-247672',
#    'evidence-740265',
#    'evidence-220309']},
#  'claim-2942': {'claim_text': 'It’s usually taken to be the fact that as carbon dioxide concentrations in the atmosphere increase, the 1 per cent of CO2 that’s the heavier carbon isotope ratio c13 declines in proportion.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-82903',
#    'evidence-973984',
#    'evidence-475329',
#    'evidence-1139573',
#    'evidence-163581',
#    'evidence-406280']},
#  'claim-1001': {'claim_text': '‘This study goes beyond statistical correlations and explores a specific process that can plausibly explain how enhanced high-latitude warming trends may trigger remote weather impacts,’ he said.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-333810',
#    'evidence-368618',
#    'evidence-463484',
#    'evidence-399850',
#    'evidence-853782',
#    'evidence-729326']},
#  'claim-1034': {'claim_text': 'Your odds of correctly guessing the outcome of a flipped coin are 1 in 2, but your odds of guessing correctly twice in a row are only 1 in 4 —',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-23786',
#    'evidence-1172200',
#    'evidence-164796',
#    'evidence-893274',
#    'evidence-636908',
#    'evidence-932992']},
#  'claim-1009': {'claim_text': '‘Arctic ice conditions have been tracking at record low conditions since October, persisting for six consecutive months’',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-927257',
#    'evidence-825435',
#    'evidence-589625',
#    'evidence-105669',
#    'evidence-422228',
#    'evidence-833407']},
#  'claim-770': {'claim_text': '[CO2] has increased 43 percent above the pre-industrial level so far',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-898871',
#    'evidence-167938',
#    'evidence-111473',
#    'evidence-998126',
#    'evidence-215825',
#    'evidence-590642']},
#  'claim-3074': {'claim_text': 'Fourth Assessment Report (AR4), in which the likely range is given as 2.0°C to 4.5°C, with a best estimate of 3.0°C" (Pat Michaels)',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1016332',
#    'evidence-526818',
#    'evidence-1033370',
#    'evidence-483878',
#    'evidence-526435',
#    'evidence-1040995']},
#  'claim-1761': {'claim_text': 'Multiple lines of evidence make it very clear that the rise in atmospheric CO2 is due to human emissions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-889101',
#    'evidence-1117728',
#    'evidence-979052',
#    'evidence-310386',
#    'evidence-950248',
#    'evidence-1180097']},
#  'claim-1475': {'claim_text': "More than 500 scientists and professionals in climate and related fields have sent a 'European Climate Declaration' to the Secretary-General of the United Nations.",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-886881',
#    'evidence-278147',
#    'evidence-1199931',
#    'evidence-997277',
#    'evidence-726970',
#    'evidence-971914']},
#  'claim-477': {'claim_text': 'Scientists say halting deforestation ‘just as urgent’ as reducing emissions',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1128272',
#    'evidence-425896',
#    'evidence-847759',
#    'evidence-1108706',
#    'evidence-890671',
#    'evidence-924766']},
#  'claim-1378': {'claim_text': 'Antarctica is gaining land-based ice, according to a new study by NASA scientists published in the Journal of Glaciology',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-529248',
#    'evidence-1033297',
#    'evidence-475376',
#    'evidence-728645',
#    'evidence-1033909',
#    'evidence-628860']},
#  'claim-503': {'claim_text': '“During the sunless winter, a heatwave raised concerns that the polar vortex may be eroding.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-760329',
#    'evidence-166500',
#    'evidence-192454',
#    'evidence-7898',
#    'evidence-590310',
#    'evidence-392970']},
#  'claim-2751': {'claim_text': 'The argument that solving the global warming problem by reducing human greenhouse gas emissions is "too hard" generally stems from the belief that (i) our technology is not sufficiently advanced to achieve significant emissions reductions,',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-326443',
#    'evidence-393913',
#    'evidence-1117213',
#    'evidence-563656',
#    'evidence-811718',
#    'evidence-675698']},
#  'claim-2575': {'claim_text': 'Over the last 30-40 years 80% of coral in the Caribbean have been destroyed and 50% in Indonesia and the Pacific.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-29065',
#    'evidence-888119',
#    'evidence-696394',
#    'evidence-123929',
#    'evidence-929518',
#    'evidence-732224']},
#  'claim-30': {'claim_text': "the bushfires [in Australia] were caused by arsonists and a series of lightning strikes, not 'climate change'",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-968437',
#    'evidence-780092',
#    'evidence-870727',
#    'evidence-629286',
#    'evidence-351418',
#    'evidence-819908']},
#  'claim-2994': {'claim_text': "'Mauna Loa has been producing a readout which supports Manning's predetermined goal by showing steady growth in atmospheric CO2 concentrations since 1959.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-66273',
#    'evidence-270748',
#    'evidence-685709',
#    'evidence-901948',
#    'evidence-269764',
#    'evidence-708522']},
#  'claim-55': {'claim_text': '[T]he raw data, the actual thermometer data[...] shows that the US has been cooling for 80 to 90 years.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-396425',
#    'evidence-1115931',
#    'evidence-44758',
#    'evidence-951329',
#    'evidence-154896',
#    'evidence-284837']},
#  'claim-1271': {'claim_text': 'Greenland ice sheet … would balloon sea levels by around 7m should it disintegrate',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1040612',
#    'evidence-173281',
#    'evidence-975453',
#    'evidence-408551',
#    'evidence-77016',
#    'evidence-264761']},
#  'claim-2248': {'claim_text': 'Climate sensitivity can be calculated empirically by comparing past temperature change to natural forcings at the time.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-78884',
#    'evidence-1008952',
#    'evidence-412505',
#    'evidence-206645',
#    'evidence-575705',
#    'evidence-1068751']},
#  'claim-532': {'claim_text': 'Never mind that the emissions of carbon dioxide to make and maintain a wind or solar industrial complex are far greater than they will ever save.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-693067',
#    'evidence-1190653',
#    'evidence-257929',
#    'evidence-247672',
#    'evidence-465371',
#    'evidence-57767']},
#  'claim-556': {'claim_text': 'The April low temperatures here are now about 6 degrees Fahrenheit warmer than they used to be.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1196923',
#    'evidence-1088556',
#    'evidence-917316',
#    'evidence-401833',
#    'evidence-345071',
#    'evidence-315466']},
#  'claim-1173': {'claim_text': '[…]until we develop a practical, cost-competitive alternative to fossil fuels, it is unlikely that renewable energy will ever make up more than 15-20% of global energy requirements.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-54484',
#    'evidence-127142',
#    'evidence-30405',
#    'evidence-400255',
#    'evidence-1159653',
#    'evidence-458427']},
#  'claim-539': {'claim_text': 'We note that the Earth has never in its history had a quasi-stable state that is around 2C warmer than the preindustrial and suggest that there is substantial risk that the system, itself, will ‘want’ to continue warming because of all of these other processes – even if we stop emissions,” she said.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-953997',
#    'evidence-906588',
#    'evidence-479642',
#    'evidence-527805',
#    'evidence-1120931',
#    'evidence-94321']},
#  'claim-893': {'claim_text': 'While France and other G7 countries lamented the U.S. exit from the Paris climate accord, America’s air is already cleaner than that of any other country in the G7, except Canada with its scant population.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-294163',
#    'evidence-241396',
#    'evidence-398722',
#    'evidence-430470',
#    'evidence-896707',
#    'evidence-226029']},
#  'claim-2857': {'claim_text': 'Weather is chaotic because air is light, it has low friction and viscosity, it expands strongly when in contact with hot surfaces and it conducts heat poorly.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-597607',
#    'evidence-726325',
#    'evidence-972046',
#    'evidence-243234',
#    'evidence-1202132',
#    'evidence-625300']},
#  'claim-109': {'claim_text': 'Local and regional sea levels continue to exhibit typical natural variability—in some places rising and in others falling.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-51367',
#    'evidence-776091',
#    'evidence-29728',
#    'evidence-242575',
#    'evidence-886636',
#    'evidence-93169']},
#  'claim-2476': {'claim_text': "The global dimming trend reversed around 1990 - 15 years after the global warming trend began in the mid 1970's.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1016008',
#    'evidence-269336',
#    'evidence-513478',
#    'evidence-256566',
#    'evidence-268994',
#    'evidence-1076601']},
#  'claim-3038': {'claim_text': 'Clearly, other factors besides atmospheric carbon influence earth temperatures and global warming."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1006052',
#    'evidence-244355',
#    'evidence-34759',
#    'evidence-774592',
#    'evidence-801082',
#    'evidence-203533']},
#  'claim-3127': {'claim_text': '"Skeptics hope that Postma’s alternative thermal model will lead  to the birth of a new climatology, one that actually follows the laws of  physics and properly physical modeling techniques...',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-62241',
#    'evidence-11275',
#    'evidence-995356',
#    'evidence-788381',
#    'evidence-740647',
#    'evidence-43104']},
#  'claim-474': {'claim_text': 'Sea ice continued its declining trend, both in the Arctic and Antarctic.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-456685',
#    'evidence-192938',
#    'evidence-320335',
#    'evidence-526245',
#    'evidence-1172097',
#    'evidence-379278']},
#  'claim-2464': {'claim_text': 'While natural forcings can account for much of the early 20th Century warming, humans played a role as well.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-539321',
#    'evidence-1138902',
#    'evidence-433258',
#    'evidence-69511',
#    'evidence-1026205',
#    'evidence-148474']},
#  'claim-2427': {'claim_text': 'By that time CO2 emissions had already risen from the expanded use  of coal that had powered the industrial revolution, and emissions only  increased slowly from 3.5gigatonnes in 1910 to under 4gigatonnes by the  end of the Second World War.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-434720',
#    'evidence-1017677',
#    'evidence-398732',
#    'evidence-241754',
#    'evidence-1147406',
#    'evidence-355045']},
#  'claim-2167': {'claim_text': 'Royal Society embraces skepticism',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-402496',
#    'evidence-904729',
#    'evidence-780416',
#    'evidence-700534',
#    'evidence-485260',
#    'evidence-834922']},
#  'claim-812': {'claim_text': 'The human contribution can be up to 30 percent or so of the total rainfall coming out of the storm',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-253475',
#    'evidence-1188377',
#    'evidence-982027',
#    'evidence-1077100',
#    'evidence-543901',
#    'evidence-587220']},
#  'claim-2590': {'claim_text': "This argument originates from Angstrom's work in 1901.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-507814',
#    'evidence-102246',
#    'evidence-437848',
#    'evidence-652349',
#    'evidence-520836',
#    'evidence-617465']},
#  'claim-404': {'claim_text': 'Actual weather records over the past 100 years show no correlation between rising carbon dioxide levels and local temperatures.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-973268',
#    'evidence-563360',
#    'evidence-81551',
#    'evidence-671685',
#    'evidence-1153298',
#    'evidence-295594']},
#  'claim-2977': {'claim_text': 'According to the study, as carbon levels have risen, the cold air at high altitudes over the tropics has actually grown colder.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-702988',
#    'evidence-427368',
#    'evidence-1175917',
#    'evidence-485904',
#    'evidence-415971',
#    'evidence-427376']},
#  'claim-2673': {'claim_text': 'They changed the name from “global warming” to “climate change” after the term global warming just wasn’t working (it was too cold)!',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-968138',
#    'evidence-54979',
#    'evidence-464021',
#    'evidence-462034',
#    'evidence-947780',
#    'evidence-109016']},
#  'claim-2509': {'claim_text': 'In 1905, PDO switched to a warm phase.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-84969',
#    'evidence-667390',
#    'evidence-410946',
#    'evidence-1136556',
#    'evidence-392246',
#    'evidence-420577']},
#  'claim-138': {'claim_text': 'As a result, half of the people surveyed around the world last year said they thought climate change would make humanity extinct.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-286580',
#    'evidence-497935',
#    'evidence-124518',
#    'evidence-15816',
#    'evidence-492222',
#    'evidence-896513']},
#  'claim-952': {'claim_text': 'The Alaskan tundra is warming so quickly it has become a net emitter of carbon dioxide ahead of schedule, a new study finds',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-966395',
#    'evidence-288351',
#    'evidence-1153298',
#    'evidence-961338',
#    'evidence-705706',
#    'evidence-695858']},
#  'claim-1691': {'claim_text': 'Sea level rise is now increasing faster than predicted due to unexpectedly rapid ice melting.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1019600',
#    'evidence-493616',
#    'evidence-849471',
#    'evidence-1154195',
#    'evidence-968727',
#    'evidence-535947']},
#  'claim-1741': {'claim_text': 'Volcanoes have had no warming effect in recent global warming - if anything, a cooling effect.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-405992',
#    'evidence-760765',
#    'evidence-210566',
#    'evidence-1142444',
#    'evidence-1076601',
#    'evidence-52772']},
#  'claim-1202': {'claim_text': '\xa0The discrepancy between model-predicted warming and (lower) real-world observations has inspired new respect for natural climate variability relative to greenhouse-gas forcing.\xa0',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-708206',
#    'evidence-208367',
#    'evidence-500451',
#    'evidence-658161',
#    'evidence-213356',
#    'evidence-681843']},
#  'claim-1028': {'claim_text': 'A second coat of paint has much less of an effect, while adding a third or fourth coat has almost no impact at all.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-644769',
#    'evidence-550189',
#    'evidence-880739',
#    'evidence-790529',
#    'evidence-1032479',
#    'evidence-629373']},
#  'claim-28': {'claim_text': 'Volcanoes Melting West Antarctic Glaciers, Not Global Warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-403673',
#    'evidence-863489',
#    'evidence-352655',
#    'evidence-372818',
#    'evidence-380361',
#    'evidence-887892']},
#  'claim-275': {'claim_text': 'until temperature increases began to slow down after 1998 and remained relatively stable for a period of 15 years',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-456473',
#    'evidence-264063',
#    'evidence-1026830',
#    'evidence-368626',
#    'evidence-112056',
#    'evidence-949456']},
#  'claim-350': {'claim_text': 'Since 1965, more parts of the U.S. have seen a decrease in flooding than have seen an increase.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-531567',
#    'evidence-1032383',
#    'evidence-290044',
#    'evidence-816328',
#    'evidence-267081',
#    'evidence-325223']},
#  'claim-2204': {'claim_text': 'All the indicators show that global warming is still happening.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-246003',
#    'evidence-449150',
#    'evidence-929949',
#    'evidence-1112727',
#    'evidence-26359',
#    'evidence-1142444']},
#  'claim-1604': {'claim_text': 'CO2 increase is natural, not human-caused.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-498380',
#    'evidence-406857',
#    'evidence-578065',
#    'evidence-178206',
#    'evidence-221841',
#    'evidence-66273']},
#  'claim-3119': {'claim_text': 'CO2 constitutes 80% of the non-condensing greenhouse gas forcing.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-578065',
#    'evidence-556098',
#    'evidence-272735',
#    'evidence-1098091',
#    'evidence-385635',
#    'evidence-256886']},
#  'claim-2150': {'claim_text': 'Adapting to global warming is cheaper than preventing it',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-339551',
#    'evidence-831754',
#    'evidence-261909',
#    'evidence-1037164',
#    'evidence-719130',
#    'evidence-813954']},
#  'claim-21': {'claim_text': 'Sea level rise has been slow and a constant, pre-dating industrialization',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-988277',
#    'evidence-534610',
#    'evidence-149013',
#    'evidence-535947',
#    'evidence-447033',
#    'evidence-1019600']},
#  'claim-2013': {'claim_text': 'U.S. Sen. Ron Johnson voted to let oil and gas companies emit "unlimited carbon pollution into our air"',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-99322',
#    'evidence-1111307',
#    'evidence-759968',
#    'evidence-1184683',
#    'evidence-453983',
#    'evidence-911831']},
#  'claim-467': {'claim_text': 'This is the South Pole ice, 90% of Earth’s ice, and it’s getting thicker.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-778795',
#    'evidence-942280',
#    'evidence-332166',
#    'evidence-566982',
#    'evidence-47181',
#    'evidence-406595']},
#  'claim-2754': {'claim_text': '"There are many urgent priorities that need the attention of Congress, and it is not for me as an invited guest in your country to say what they are.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1113921',
#    'evidence-729429',
#    'evidence-63436',
#    'evidence-998340',
#    'evidence-995514',
#    'evidence-422989']},
#  'claim-2797': {'claim_text': 'Global brightening is caused by changes in cloud cover, reflective aerosols and absorbing aerosols.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-975125',
#    'evidence-1061504',
#    'evidence-903304',
#    'evidence-644779',
#    'evidence-989213',
#    'evidence-40622']},
#  'claim-1771': {'claim_text': 'Peer-reviewed research, physics, and math all tell us that a grand solar minimum would have no more than a 0.3°C cooling effect, barely enough to put a dent in human-caused global warming.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1091739',
#    'evidence-888023',
#    'evidence-401724',
#    'evidence-530414',
#    'evidence-1114420',
#    'evidence-423735']},
#  'claim-1908': {'claim_text': 'In reality, gas produced by fracking is worse for the climate than coal.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-555993',
#    'evidence-102664',
#    'evidence-399798',
#    'evidence-241989',
#    'evidence-1065464',
#    'evidence-939851']},
#  'claim-2000': {'claim_text': 'There is not a single candidate in the Republican primary that thinks we should do anything about climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-91013',
#    'evidence-850174',
#    'evidence-385259',
#    'evidence-555869',
#    'evidence-1163186',
#    'evidence-933826']},
#  'claim-2084': {'claim_text': "Hurricanes aren't linked to global warming",
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-280904',
#    'evidence-853782',
#    'evidence-29528',
#    'evidence-57888',
#    'evidence-1167418',
#    'evidence-35625']},
#  'claim-1237': {'claim_text': 'the last sea-level high point, … occurred between the last two ice ages, about 125,000 years ago.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-623810',
#    'evidence-1059229',
#    'evidence-796667',
#    'evidence-373203',
#    'evidence-1118732',
#    'evidence-663304']},
#  'claim-400': {'claim_text': 'The idea that climate change is producing heat records across the Earth is among the most egregious manipulations of data in the absurd global warming debate.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-939303',
#    'evidence-957593',
#    'evidence-495289',
#    'evidence-480552',
#    'evidence-250707',
#    'evidence-26359']},
#  'claim-1508': {'claim_text': 'global warming ceased around the end of the twentieth century and was followed (since 1997) by 19 years of stable temperature.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-323590',
#    'evidence-138090',
#    'evidence-1975',
#    'evidence-279946',
#    'evidence-1142528',
#    'evidence-617105']},
#  'claim-520': {'claim_text': 'Just 1.25 per cent of the carbon dioxide in the atmosphere-ocean system has been released by \xadhumans in the past 250 years.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-156413',
#    'evidence-1042127',
#    'evidence-660815',
#    'evidence-294915',
#    'evidence-1006302',
#    'evidence-839069']},
#  'claim-3064': {'claim_text': 'No warming since at least 1995, no melting glaciers and now no rising sea levels.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1088478',
#    'evidence-240414',
#    'evidence-1142444',
#    'evidence-902893',
#    'evidence-118577',
#    'evidence-508668']},
#  'claim-1588': {'claim_text': "Melting ice isn't warming the Arctic.",
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-298628',
#    'evidence-1030127',
#    'evidence-1173602',
#    'evidence-1054441',
#    'evidence-384274',
#    'evidence-333694']},
#  'claim-1488': {'claim_text': 'New Study Confirms EVs Considerably Worse For Climate Than Diesel Cars.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-254515',
#    'evidence-862662',
#    'evidence-556972',
#    'evidence-729613',
#    'evidence-1033987',
#    'evidence-562938']},
#  'claim-2733': {'claim_text': 'A number of independent studies using near-global satellite data find positive feedback and high climate sensitivity.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-228393',
#    'evidence-711945',
#    'evidence-848463',
#    'evidence-223495',
#    'evidence-1152675',
#    'evidence-627854']},
#  'claim-809': {'claim_text': 'In the early 20th century, state and federal governments began aggressively fighting wildfires and trying to keep them as small as possible.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1044216',
#    'evidence-1007677',
#    'evidence-584308',
#    'evidence-959566',
#    'evidence-709753',
#    'evidence-730284']},
#  'claim-763': {'claim_text': 'And some plants – like algae which use carbon for photosynthesis – may even benefit.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-886259',
#    'evidence-600206',
#    'evidence-171037',
#    'evidence-527118',
#    'evidence-345397',
#    'evidence-1203326']},
#  'claim-454': {'claim_text': 'Man-made greenhouse gases play only an insignificant role.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-718133',
#    'evidence-147653',
#    'evidence-445289',
#    'evidence-738040',
#    'evidence-313064',
#    'evidence-1195163']},
#  'claim-1853': {'claim_text': 'Barack Obama supports proposals "to devote billions of dollars annually to state game and fish agencies and federal land management agencies to help them ensure that fish and wildlife survive the impacts of climate change."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-551085',
#    'evidence-972641',
#    'evidence-608846',
#    'evidence-272973',
#    'evidence-472283',
#    'evidence-653867']},
#  'claim-2838': {'claim_text': "The data is being reported by the University of Illinois's Arctic Climate Research Center, and is derived from satellite observations of the Northern and Southern hemisphere polar regions (Daily Tech).",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-117846',
#    'evidence-74163',
#    'evidence-501093',
#    'evidence-172532',
#    'evidence-941321',
#    'evidence-32773']},
#  'claim-2028': {'claim_text': 'cutting speed limits could slow climate change',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-278964',
#    'evidence-983076',
#    'evidence-282904',
#    'evidence-1178287',
#    'evidence-1006823',
#    'evidence-795968']},
#  'claim-2434': {'claim_text': 'The IPCC blames human emissions of carbon dioxide for the last  warming.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-874622',
#    'evidence-193199',
#    'evidence-552836',
#    'evidence-465371',
#    'evidence-22668',
#    'evidence-837056']},
#  'claim-298': {'claim_text': 'Only very few peer-reviewed papers even go so far as to say that recent warming is chiefly anthropogenic.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1086003',
#    'evidence-3046',
#    'evidence-122015',
#    'evidence-365482',
#    'evidence-231304',
#    'evidence-784005']},
#  'claim-338': {'claim_text': 'Rapid assessment of average temperatures in France between 26-28 June showed a “substantial” increase in the likelihood of the heatwave happening as a result of human-caused global warming, experts at the World Weather Attribution group said.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-320649',
#    'evidence-594052',
#    'evidence-876272',
#    'evidence-1192872',
#    'evidence-417371',
#    'evidence-603626']},
#  'claim-1672': {'claim_text': 'Global temperature is still rising and 2010 was the hottest recorded.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-922640',
#    'evidence-975224',
#    'evidence-917316',
#    'evidence-915569',
#    'evidence-130662',
#    'evidence-118792']},
#  'claim-2840': {'claim_text': 'Arctic sea ice is also falling at an accelerated rate.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1034941',
#    'evidence-1043067',
#    'evidence-298127',
#    'evidence-389854',
#    'evidence-111881',
#    'evidence-240134']},
#  'claim-1425': {'claim_text': 'Each year sees the disappearance of thousands of plant and animal species which we will never know, which our children will never see, because they have been lost for ever.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-126437',
#    'evidence-1034275',
#    'evidence-820927',
#    'evidence-230516',
#    'evidence-545497',
#    'evidence-741452']},
#  'claim-1985': {'claim_text': 'The North Pole is melting "a bit" but the South Pole is getting bigger.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1062078',
#    'evidence-626530',
#    'evidence-1181035',
#    'evidence-879989',
#    'evidence-216604',
#    'evidence-950574']},
#  'claim-1156': {'claim_text': 'The costs of emissions regulations, which will be paid by everyone, will be punishingly high and will provide no benefits to most people anywhere in the world.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-308686',
#    'evidence-230516',
#    'evidence-1115787',
#    'evidence-472182',
#    'evidence-17471',
#    'evidence-229113']},
#  'claim-2870': {'claim_text': "Ironically, it's those who are mispresenting Hulme's paper that are the ones being misleading.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-434109',
#    'evidence-316670',
#    'evidence-357575',
#    'evidence-784277',
#    'evidence-965213',
#    'evidence-973435']},
#  'claim-2898': {'claim_text': 'The report suggests significantly smaller overall  ice-mass losses than previous estimates.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-591671',
#    'evidence-76212',
#    'evidence-755421',
#    'evidence-1192903',
#    'evidence-100347',
#    'evidence-176029']},
#  'claim-2329': {'claim_text': 'We know the Northwest Passage had been open before."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-956029',
#    'evidence-608200',
#    'evidence-866503',
#    'evidence-699759',
#    'evidence-862569',
#    'evidence-833746']},
#  'claim-1998': {'claim_text': 'There is a link between climate change and the NSW bushfires.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-776089',
#    'evidence-237546',
#    'evidence-954569',
#    'evidence-446251',
#    'evidence-982161',
#    'evidence-496897']},
#  'claim-2209': {'claim_text': 'Surface temperatures can show short-term cooling when heat is exchanged between the atmosphere and the ocean, which has a much greater heat capacity than the air.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-691017',
#    'evidence-685129',
#    'evidence-73691',
#    'evidence-1035786',
#    'evidence-202320',
#    'evidence-1171194']},
#  'claim-1582': {'claim_text': "Tuvalu sea level isn't rising.",
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-98543',
#    'evidence-136458',
#    'evidence-485236',
#    'evidence-1133838',
#    'evidence-559936',
#    'evidence-349302']},
#  'claim-3072': {'claim_text': '"a paper...in Science magazine concludes that the climate sensitivity—how much the earth’s average temperature will rise as a result of a doubling of the atmospheric concentration of carbon dioxide—likely (that is, with a 66% probability) lies in the range 1.7°C to 2.6°C, with a median value of 2.3°C.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1196020',
#    'evidence-918450',
#    'evidence-852366',
#    'evidence-915569',
#    'evidence-940847',
#    'evidence-956940']},
#  'claim-381': {'claim_text': '[subsidies for wind and solar] add to emissions because coal-fired elec\xadtricity needs to be on standby for when there is no wind or sunshine.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-829138',
#    'evidence-68457',
#    'evidence-1162596',
#    'evidence-119923',
#    'evidence-387250',
#    'evidence-987398']},
#  'claim-398': {'claim_text': 'nothing we can do to stop the Earth’s naturally occurring climate cycles.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-53751',
#    'evidence-803092',
#    'evidence-1163186',
#    'evidence-65296',
#    'evidence-1132438',
#    'evidence-175965']},
#  'claim-1560': {'claim_text': 'Sea level rise predictions are exaggerated.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-988277',
#    'evidence-149013',
#    'evidence-535947',
#    'evidence-447033',
#    'evidence-336860',
#    'evidence-1019600']},
#  'claim-2246': {'claim_text': '"His [Dr Spencer\'s] latest research demonstrates that – in the short term, at any rate –  the temperature feedbacks that the IPCC imagines will greatly amplify  any initial warming caused by CO2 are net-negative, attenuating the  warming they are supposed to enhance.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-429754',
#    'evidence-448411',
#    'evidence-59539',
#    'evidence-700183',
#    'evidence-807986',
#    'evidence-572309']},
#  'claim-2774': {'claim_text': 'Actual reconstructions "diverge" from the instrumental series in the last part of 20th century.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-698119',
#    'evidence-663591',
#    'evidence-104236',
#    'evidence-604963',
#    'evidence-1131132',
#    'evidence-362871']},
#  'claim-972': {'claim_text': '“Arctic land stores about twice as much carbon as the atmosphere.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-248795',
#    'evidence-1026205',
#    'evidence-298823',
#    'evidence-22100',
#    'evidence-750003',
#    'evidence-620559']},
#  'claim-1531': {'claim_text': 'Earth’s climate is now changing faster than at any point in the history of modern civilization, primarily as a result of human activities.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1165306',
#    'evidence-881339',
#    'evidence-359762',
#    'evidence-135825',
#    'evidence-41804',
#    'evidence-175965']},
#  'claim-2592': {'claim_text': '"A July 6, 2007 study published in the journal Science about Greenland by an international team of scientists found DNA “evidence that suggests the frozen shield covering the immense island survived the Earth’s last period of global warming,” according to a Boston Globe Article. \xa0...',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-963115',
#    'evidence-767213',
#    'evidence-289552',
#    'evidence-110766',
#    'evidence-163807',
#    'evidence-1186526']},
#  'claim-2468': {'claim_text': '"Satellite measurements indicate an absence of significant global warming since 1979, the very period that human carbon dioxide emissions have been increasing rapidly.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1142444',
#    'evidence-1975',
#    'evidence-1117137',
#    'evidence-801082',
#    'evidence-491362',
#    'evidence-597084']},
#  'claim-463': {'claim_text': '“So now we’re able to explain from natural factors how we’ve had the 20th Century warming.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-784446',
#    'evidence-519752',
#    'evidence-873862',
#    'evidence-1094106',
#    'evidence-1105982',
#    'evidence-687009']},
#  'claim-616': {'claim_text': 'The effect of long-term warming is to make it harder to count on snowmelt runoff in wet times',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1104960',
#    'evidence-956627',
#    'evidence-276438',
#    'evidence-40947',
#    'evidence-495325',
#    'evidence-198997']},
#  'claim-1240': {'claim_text': '“Ice-free means the central basin of the Arctic will be ice-free',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-991674',
#    'evidence-1019032',
#    'evidence-114604',
#    'evidence-731434',
#    'evidence-586254',
#    'evidence-889787']},
#  'claim-2951': {'claim_text': 'The two most cited composites are PMOD and ACRIM.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-491726',
#    'evidence-1204265',
#    'evidence-1199422',
#    'evidence-439170',
#    'evidence-191669',
#    'evidence-758598']},
#  'claim-1977': {'claim_text': 'The climate-change agreement between the United States and China "requires the Chinese to do nothing at all for 16 years."',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-7632',
#    'evidence-118226',
#    'evidence-162847',
#    'evidence-97647',
#    'evidence-852827',
#    'evidence-1147452']},
#  'claim-942': {'claim_text': '‘We could be decades too fast, or decades too slow,’said one of them, Robert M. DeConto of the University of Massachusetts, Amherst.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-613429',
#    'evidence-306088',
#    'evidence-603880',
#    'evidence-92107',
#    'evidence-308460',
#    'evidence-104592']},
#  'claim-2755': {'claim_text': 'Global warming is an increasingly urgent problem.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-18613',
#    'evidence-679356',
#    'evidence-799984',
#    'evidence-540292',
#    'evidence-521030',
#    'evidence-255653']},
#  'claim-1230': {'claim_text': 'On the Pacific Coast, a climate pattern that had pushed billions of gallons of water toward Asia is now ending, so that in coming decades the sea is likely to rise quickly off states like Oregon and California.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-974738',
#    'evidence-847365',
#    'evidence-775949',
#    'evidence-903996',
#    'evidence-277577',
#    'evidence-680246']},
#  'claim-3123': {'claim_text': 'Given that a doubling of carbon dioxide would change the surface heat flux by only two watts per square meter, it is evident that a small change in cloud cover can strongly affect the response to carbon dioxide."',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-725977',
#    'evidence-1204499',
#    'evidence-666859',
#    'evidence-977413',
#    'evidence-223619',
#    'evidence-575705']},
#  'claim-1684': {'claim_text': 'The 2nd law of thermodynamics is consistent with the greenhouse effect which is directly observed.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-22380',
#    'evidence-183766',
#    'evidence-607965',
#    'evidence-45568',
#    'evidence-1186736',
#    'evidence-256785']},
#  'claim-839': {'claim_text': '“Even if we meet the Paris goals of two degrees warming, cities like Karachi and Kolkata will become close to uninhabitable, annually encountering deadly heat waves like those that crippled them in 2015.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-590962',
#    'evidence-1018053',
#    'evidence-898847',
#    'evidence-283907',
#    'evidence-1003759',
#    'evidence-386943']},
#  'claim-2423': {'claim_text': 'Arctic sea ice has been steadily thinning, even in the last few years while the surface ice (eg - sea ice extent) increased slightly.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-728645',
#    'evidence-1181544',
#    'evidence-240134',
#    'evidence-1116441',
#    'evidence-614586',
#    'evidence-185095']},
#  'claim-1243': {'claim_text': 'by that I mean the central Arctic will be ice-free.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1019032',
#    'evidence-230516',
#    'evidence-586254',
#    'evidence-248217',
#    'evidence-957020',
#    'evidence-528490']},
#  'claim-494': {'claim_text': 'The Massachusetts Bay Colony in 1635 experienced a Category 3 or 4 storm, with up to a 20-foot storm surge.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-913373',
#    'evidence-268348',
#    'evidence-382309',
#    'evidence-179166',
#    'evidence-321135',
#    'evidence-963669']},
#  'claim-1458': {'claim_text': 'Glaciers are retreating almost everywhere around the world — including in the Alps, Himalayas, Andes, Rockies, Alaska and Africa.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-947076',
#    'evidence-353546',
#    'evidence-725428',
#    'evidence-866329',
#    'evidence-1160493',
#    'evidence-910923']},
#  'claim-461': {'claim_text': 'Temperatures cooled from about 1940 to 1975, and then they rose from about ’75 to about 2005 or so, and since then they’ve been flat or cooling.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-721068',
#    'evidence-940260',
#    'evidence-497903',
#    'evidence-1207830',
#    'evidence-586920',
#    'evidence-609220']},
#  'claim-1304': {'claim_text': 'in a letter to The Times from Lord Krebs and company, essentially telling the newspaper to stop reporting less-than-negative climate stories.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-167546',
#    'evidence-353049',
#    'evidence-748804',
#    'evidence-945024',
#    'evidence-716536',
#    'evidence-879759']},
#  'claim-2564': {'claim_text': 'This small warming is  likely a result of the natural alterations in global ocean currents  which are driven by ocean salinity variations.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-56609',
#    'evidence-818420',
#    'evidence-265066',
#    'evidence-686575',
#    'evidence-758479',
#    'evidence-621571']},
#  'claim-2121': {'claim_text': 'Infrared Iris will reduce global warming',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-597452',
#    'evidence-1068590',
#    'evidence-959844',
#    'evidence-195369',
#    'evidence-429029',
#    'evidence-572309']},
#  'claim-2631': {'claim_text': 'The temperatures are expected to change by as much as 10 Fahrenheit degrees at different places of the globe.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-401833',
#    'evidence-1196923',
#    'evidence-600294',
#    'evidence-877608',
#    'evidence-917316',
#    'evidence-1088556']},
#  'claim-1141': {'claim_text': '“While record low sea ice is nothing new in the Arctic, this is a surprising turn of events for the Antarctic.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-376932',
#    'evidence-456685',
#    'evidence-172951',
#    'evidence-1124123',
#    'evidence-482300',
#    'evidence-607299']},
#  'claim-2398': {'claim_text': 'While there are direct ways in which CO2 is a pollutant (acidification of the ocean), its primary impact is its greenhouse warming effect.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-753386',
#    'evidence-791159',
#    'evidence-871850',
#    'evidence-578065',
#    'evidence-1148302',
#    'evidence-665317']},
#  'claim-1048': {'claim_text': 'While transient weather variability is playing a key role here, the widespread record warmth across the U.S. so far this year is part of a long-term trend toward more warm temperature records versus cold ones.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-508793',
#    'evidence-770937',
#    'evidence-819001',
#    'evidence-262130',
#    'evidence-409487',
#    'evidence-190984']},
#  'claim-2783': {'claim_text': 'The study indicates far less future global warming will occur than United Nations computer models have predicted, and supports prior studies indicating increases in atmospheric carbon dioxide trap far less heat than alarmists have claimed.',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-1199736',
#    'evidence-1041175',
#    'evidence-195593',
#    'evidence-597084',
#    'evidence-1093172',
#    'evidence-900964']},
#  'claim-1003': {'claim_text': 'A recent study in Nature Geoscience, for instance, called into question whether the Arctic’s melting, and in particular its sea ice loss, has been causing winter cooling over Eurasia, another idea that has been swept up in the debate over the jet stream and weather extremes.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1186766',
#    'evidence-1095432',
#    'evidence-132730',
#    'evidence-636980',
#    'evidence-411817',
#    'evidence-903119']},
#  'claim-1872': {'claim_text': 'Donald Trump claims Global Warming is a hoax',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1160675',
#    'evidence-403673',
#    'evidence-863489',
#    'evidence-695610',
#    'evidence-372818',
#    'evidence-1000186']},
#  'claim-1842': {'claim_text': 'A video shows Koko the gorilla spontaneously using sign language to issue a warning about climate change.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-570779',
#    'evidence-631984',
#    'evidence-1073982',
#    'evidence-146650',
#    'evidence-1099179',
#    'evidence-279160']},
#  'claim-2411': {'claim_text': 'Note that computer models are just concatenations of calculations you could do on a hand-held calculator, so they are theoretical and cannot be part of any evidence."',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-698760',
#    'evidence-915814',
#    'evidence-9909',
#    'evidence-1098679',
#    'evidence-281765',
#    'evidence-425838']},
#  'claim-2428': {'claim_text': 'It was the post war  industrialization that caused the rapid rise in global CO2 emissions,  but by 1945 when this began, the Earth was already in a cooling phase  that started around 1942 and continued until 1975.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1147401',
#    'evidence-430265',
#    'evidence-80695',
#    'evidence-13795',
#    'evidence-601797',
#    'evidence-93242']},
#  'claim-1198': {'claim_text': '” ‘You see, gas in America is incredibly cheap, because of fracking,’ he says.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-758249',
#    'evidence-506265',
#    'evidence-769165',
#    'evidence-827119',
#    'evidence-658428',
#    'evidence-256211']},
#  'claim-678': {'claim_text': 'In the process, the cows will emit much greenhouse gas, and they will consume far more calories in beans than they will yield in meat, meaning far more clearcutting of forests to farm cattle feed than would be necessary if the beans above were simply eaten by people.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-753346',
#    'evidence-176443',
#    'evidence-308575',
#    'evidence-564587',
#    'evidence-680564',
#    'evidence-859315']},
#  'claim-2105': {'claim_text': 'Excess CO2 from human emissions has a long residence time of over 100 years',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-272735',
#    'evidence-880328',
#    'evidence-611084',
#    'evidence-703260',
#    'evidence-988851',
#    'evidence-98914']},
#  'claim-648': {'claim_text': '‘there will not be enough nitrogen available to sustain the high carbon uptake scenarios.’',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-501050',
#    'evidence-48249',
#    'evidence-352767',
#    'evidence-177069',
#    'evidence-868892',
#    'evidence-1101645']},
#  'claim-822': {'claim_text': 'Climate policy must compete with other long-term threats for always-scarce resources.”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-778434',
#    'evidence-400107',
#    'evidence-373595',
#    'evidence-37040',
#    'evidence-331347',
#    'evidence-1067907']},
#  'claim-2561': {'claim_text': 'Observed sea levels are actually tracking at the upper range of the IPCC projections.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1164059',
#    'evidence-905854',
#    'evidence-1115102',
#    'evidence-948508',
#    'evidence-4318',
#    'evidence-307667']},
#  'claim-2219': {'claim_text': 'The increase in temperatures since 1975 is a consistent feature of all reconstructions.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-551523',
#    'evidence-323541',
#    'evidence-456688',
#    'evidence-505861',
#    'evidence-718657',
#    'evidence-486519']},
#  'claim-1343': {'claim_text': 'roughly three-quarters of the tidal flood days now occurring in towns along the East Coast would not be happening in the absence of the rise in the sea level caused by human emissions.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-791175',
#    'evidence-463833',
#    'evidence-668284',
#    'evidence-1132303',
#    'evidence-898741',
#    'evidence-877693']},
#  'claim-1351': {'claim_text': 'a marginally significant warming trend in the data over the past several years, erasing the temperature plateau that vexed climate alarmists have found difficult to explain.',
#   'claim_label': 'DISPUTED',
#   'evidences': ['evidence-494851',
#    'evidence-888195',
#    'evidence-184934',
#    'evidence-774035',
#    'evidence-852366',
#    'evidence-1028174']},
#  'claim-2347': {'claim_text': 'In truth, the overwhelming majority of climate-research funding comes from the federal government and left-wing foundations.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-260640',
#    'evidence-155175',
#    'evidence-486546',
#    'evidence-882053',
#    'evidence-378893',
#    'evidence-1036392']},
#  'claim-293': {'claim_text': 'When the measuring equipment gets old and needs replacing, it often requires re-calibration.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-348717',
#    'evidence-685851',
#    'evidence-815018',
#    'evidence-1052510',
#    'evidence-371131',
#    'evidence-794271']},
#  'claim-910': {'claim_text': 'The cement, iron and steel, and petroleum refining industries could see their production cut by 21% 19%, and 11% respectively.”',
#   'claim_label': 'REFUTES',
#   'evidences': ['evidence-197221',
#    'evidence-11630',
#    'evidence-818020',
#    'evidence-68521',
#    'evidence-790714',
#    'evidence-117114']},
#  'claim-2815': {'claim_text': 'A new peer-reviewed study on Surface Warming and the Solar Cycle found that times of high solar activity are on average 0.2°C warmer than times of low solar activity, and that there is a polar amplification of the warming.',
#   'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-786294',
#    'evidence-333167',
#    'evidence-488391',
#    'evidence-280109',
#    'evidence-738284',
#    'evidence-649113']},
#  'claim-1652': {'claim_text': 'The strong CO2 effect has been observed by many different measurements.',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-229532',
#    'evidence-176805',
#    'evidence-132348',
#    'evidence-1049076',
#    'evidence-98914',
#    'evidence-603226']},
#  'claim-1212': {'claim_text': '(In technical lingo, the so-called social cost of carbon would be negative.)”',
#   'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-594802',
#    'evidence-517788',
#    'evidence-86066',
#    'evidence-270854',
#    'evidence-92472',
#    'evidence-565962']}}

# %%
with open('../test-claims-predictions.json', 'r') as final_json:
    final_test = json.load(final_json)

label_list = []
for i in test_np:
    similarity = []
    for j in train_np:
        similarity.append(cosine_similarity(np.reshape(i, (1, -1)), np.reshape(j, (1, -1)))[0][0])
    top_index = np.argsort(similarity)[-11:]
    label_list.append(list(top_index))

# %%
def most_frequent_element(nums):
    return max(set(nums), key=nums.count)

train_key_list = list(tclaim_data.keys())
test_key_list = list(final_test.keys())
for i in range(len(label_list)):
    label_list_potential = []
    for j in label_list[i]:
        label_list_potential.append(tclaim_data[train_key_list[j]]["claim_label"])
    test_class = (most_frequent_element(label_list_potential))
    # test_class = (tclaim_data[train_key_list[label_list[i]]]["claim_label"])
    final_test[test_key_list[i]]["claim_label"] = test_class

# %%
file_path = '../test-claims-predictions.json'
with open(file_path, 'w') as json_file:
    json.dump(final_test, json_file)
